# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def resumen(datos):
    return print('Forma:\n', datos.shape,'\n\n',
                 'Columnas:\n', datos.columns,'\n\n',
                 'Tipos:\n', datos.dtypes,'\n\n',
                 'Datos nulos:\n', datos.isnull().sum(),'\n\n',
                 'Cabecera:\n', datos.head(10),'\n\n',
                 'Últimos datos:\n', datos.tail(10),'\n\n',
                 'Estadísticos:\n', datos.describe([0.05,0.25,0.5,0.75,0.95])
                )
def truncar(numero, decimales = 0):
    return np.trunc(numero*10**decimales)/(10**decimales)

# %%
def metadata(ejex, ejey):
    # plt.title(titulo, fontsize = 60, fontweight='bold')
    plt.xlabel(ejex, fontsize = 35)
    plt.ylabel(ejey, fontsize = 35)
    plt.xticks(fontsize = 25)
    plt.yticks(fontsize = 25)
    return
def cifras_signif(i, cifras = 3):
    texto = str('{:g}'.format(float('{:.{p}g}'.format(i, p = cifras))))
    return texto

# %%
jun = pd.read_csv(#'C:\\Users\\nahue\\Desktop\\Tesis_2\\Datos\\Relleno_jun.txt',
                        'C:\\Users\\BIOMET\\Desktop\\Tesis_2\\Datos\\Relleno_jun.txt',
                        delimiter = '\t',
                        decimal = '.',
                        na_values = -9999,
                        encoding = 'ascii'
                        )

# %%
resumen(jun)
# Out:
# Forma:
#  (14442, 3)
#
#  Columnas:
#  Index(['DoY', 'Hour', 'NEE'], dtype='object')
#
#  Tipos:
#  DoY     float64
# Hour    float64
# NEE     float64
# dtype: object
#
#  Datos nulos:
#  DoY     0
# Hour    0
# NEE     0
# dtype: int64
#
#  Cabecera:
#      DoY    Hour       NEE
# 0  54.0   9.125 -2.895017
# 1  54.0   9.625 -2.706527
# 2  54.0  10.125 -3.167786
# 3  54.0  10.625 -2.967365
# 4  54.0  11.125 -3.263207
# 5  54.0  11.625 -3.253597
# 6  54.0  12.125 -3.232202
# 7  54.0  12.625 -3.162727
# 8  54.0  13.125 -3.072364
# 9  54.0  13.625 -3.036975
#
#  Últimos datos:
#           DoY   Hour       NEE
# 14432  355.0  1.125  3.348183
# 14433  355.0  1.625 -0.134767
# 14434  355.0  2.125  3.534733
# 14435  355.0  2.625  3.814917
# 14436  355.0  3.125  1.830471
# 14437  355.0  3.625  2.232971
# 14438  355.0  4.125  3.119500
# 14439  355.0  4.625  4.953000
# 14440  355.0  5.125  3.257767
# 14441  355.0  5.625  1.384700
#
#  Estadísticos:
# ...

# %%
feb = pd.read_csv(#'C:\\Users\\nahue\\Desktop\\Tesis_2\\Datos\\Relleno_feb.txt',
                        'C:\\Users\\BIOMET\\Desktop\\Tesis_2\\Datos\\Relleno_feb.txt',
                        delimiter = '\t',
                        decimal = '.',
                        na_values = -9999,
                        encoding = 'ascii'
                        )
anu = pd.read_csv(#'C:\\Users\\nahue\\Desktop\\Tesis_2\\Datos\\Relleno_anu.txt',
                        'C:\\Users\\BIOMET\\Desktop\\Tesis_2\\Datos\\Relleno_anu.txt',
                        delimiter = '\t',
                        decimal = '.',
                        na_values = -9999,
                        encoding = 'ascii'
                        )

# %%
resumen(feb)
# Out:
# Forma:
#  (14442, 3)
#
#  Columnas:
#  Index(['DoY', 'Hour', 'NEE'], dtype='object')
#
#  Tipos:
#  DoY     float64
# Hour    float64
# NEE     float64
# dtype: object
#
#  Datos nulos:
#  DoY     0
# Hour    0
# NEE     0
# dtype: int64
#
#  Cabecera:
#      DoY    Hour       NEE
# 0  54.0   9.125 -3.999143
# 1  54.0   9.625 -3.826492
# 2  54.0  10.125 -4.231247
# 3  54.0  10.625 -4.055085
# 4  54.0  11.125 -4.303337
# 5  54.0  11.625 -4.287816
# 6  54.0  12.125 -4.263594
# 7  54.0  12.625 -4.199607
# 8  54.0  13.125 -4.119161
# 9  54.0  13.625 -4.087903
#
#  Últimos datos:
#           DoY   Hour       NEE
# 14432  355.0  1.125  3.348183
# 14433  355.0  1.625 -0.134767
# 14434  355.0  2.125  3.534733
# 14435  355.0  2.625  3.814917
# 14436  355.0  3.125  1.830471
# 14437  355.0  3.625  2.232971
# 14438  355.0  4.125  3.119500
# 14439  355.0  4.625  4.953000
# 14440  355.0  5.125  3.257767
# 14441  355.0  5.625  1.384700
#
#  Estadísticos:
# ...

# %%
resumen(anu)
# Out:
# Forma:
#  (14442, 3)
#
#  Columnas:
#  Index(['DoY', 'Hour', 'NEE'], dtype='object')
#
#  Tipos:
#  DoY     float64
# Hour    float64
# NEE     float64
# dtype: object
#
#  Datos nulos:
#  DoY     0
# Hour    0
# NEE     0
# dtype: int64
#
#  Cabecera:
#      DoY    Hour       NEE
# 0  54.0   9.125 -1.367509
# 1  54.0   9.625 -1.226079
# 2  54.0  10.125 -1.470982
# 3  54.0  10.625 -1.314161
# 4  54.0  11.125 -1.466247
# 5  54.0  11.625 -1.403608
# 6  54.0  12.125 -1.338671
# 7  54.0  12.625 -1.235606
# 8  54.0  13.125 -1.117169
# 9  54.0  13.625 -1.070909
#
#  Últimos datos:
#           DoY   Hour       NEE
# 14432  355.0  1.125  3.348183
# 14433  355.0  1.625 -0.134767
# 14434  355.0  2.125  3.534733
# 14435  355.0  2.625  3.814917
# 14436  355.0  3.125  1.830471
# 14437  355.0  3.625  2.232971
# 14438  355.0  4.125  3.119500
# 14439  355.0  4.625  4.953000
# 14440  355.0  5.125  3.257767
# 14441  355.0  5.625  1.384700
#
#  Estadísticos:
# ...

# %%
lut = pd.read_csv(#'C:\\Users\\nahue\\Desktop\\Tesis_2\\Datos\\Relleno_LUT.txt',
                    'C:\\Users\\BIOMET\\Desktop\\Tesis_2\\Datos\\Relleno_LUT.txt',
                    delimiter = '\t',
                    decimal = '.',
                    na_values = -9999,
                    encoding = 'ascii'
                    )

# %%
resumen(lut)
# Out:
# Forma:
#  (14442, 3)
#
#  Columnas:
#  Index(['DoY', 'Hour', 'NEE'], dtype='object')
#
#  Tipos:
#  DoY     float64
# Hour    float64
# NEE     float64
# dtype: object
#
#  Datos nulos:
#  DoY     0
# Hour    0
# NEE     0
# dtype: int64
#
#  Cabecera:
#      DoY    Hour        NEE
# 0  54.0   9.125  -4.710450
# 1  54.0   9.625  -4.233050
# 2  54.0  10.125  -6.151575
# 3  54.0  10.625  -5.459000
# 4  54.0  11.125  -9.687892
# 5  54.0  11.625 -10.156300
# 6  54.0  12.125  -8.480850
# 7  54.0  12.625  -3.832450
# 8  54.0  13.125  -2.628850
# 9  54.0  13.625  -2.795167
#
#  Últimos datos:
#           DoY   Hour       NEE
# 14432  355.0  1.125  3.348183
# 14433  355.0  1.625 -0.134767
# 14434  355.0  2.125  3.534733
# 14435  355.0  2.625  3.814917
# 14436  355.0  3.125  1.830471
# 14437  355.0  3.625  2.232971
# 14438  355.0  4.125  3.119500
# 14439  355.0  4.625  4.953000
# 14440  355.0  5.125  3.257767
# 14441  355.0  5.625  1.384700
#
#  Estadísticos:
# ...

# %%
reichestein = pd.read_csv(#'C:\\Users\\nahue\\Desktop\\Tesis_2\\Datos\\output.txt',
                        'C:\\Users\\BIOMET\\Desktop\\Tesis_2\\Datos\\output.txt',
                        delimiter = '\t',
                        decimal = '.',
                        na_values = -9999,
                        encoding = 'ascii',
                        skiprows = [1, 14444]
                        )

# %%
resumen(reichestein)
# Out:
# Forma:
#  (14442, 119)
#
#  Columnas:
#  Index(['Year', 'DoY', 'Hour', 'NEE', 'LE', 'H', 'Rg', 'Tair', 'Tsoil', 'rH',
#        ...
#        'FP_E0', 'FP_k_sd', 'FP_beta_sd', 'FP_alpha_sd', 'FP_RRef_sd',
#        'FP_E0_sd', 'Reco_DT', 'GPP_DT', 'Reco_DT_SD', 'GPP_DT_SD'],
#       dtype='object', length=119)
#
#  Tipos:
#  Year               int64
# DoY                int64
# Hour             float64
# NEE              float64
# LE               float64
# H                float64
# Rg               float64
# Tair             float64
# Tsoil            float64
# rH               float64
# VPD              float64
# Ustar            float64
# season             int64
# Ustar_Thres      float64
# Ustar_fqc          int64
# NEE_orig         float64
# NEE_f            float64
# NEE_fqc            int64
# NEE_fall         float64
# NEE_fall_qc        int64
# NEE_fnum           int64
# NEE_fsd          float64
# NEE_fmeth          int64
# NEE_fwin           int64
# LE_orig          float64
# ...

# %%
comparacion = reichestein[['DoY', 'Hour', 'NEE', 'NEE_f']][:]
comparacion.head()
# Out:
#    DoY  Hour  NEE     NEE_f
# 0   54   9.0  NaN -5.630867
# 1   54   9.5  NaN -4.823325
# 2   54  10.0  NaN -6.212467
# 3   54  10.5  NaN -3.625855
# 4   54  11.0  NaN -7.545225

# %%
comparacion['NEE LUT'] = lut['NEE'][:]
comparacion['NEE anu'] = anu['NEE'][:]
comparacion['NEE feb'] = feb['NEE'][:]
comparacion['NEE jun'] = jun['NEE'][:]
comparacion.head()
# Out:
#    DoY  Hour  NEE     NEE_f   NEE LUT   NEE anu   NEE feb   NEE jun
# 0   54   9.0  NaN -5.630867 -4.710450 -1.367509 -3.999143 -2.895017
# 1   54   9.5  NaN -4.823325 -4.233050 -1.226079 -3.826492 -2.706527
# 2   54  10.0  NaN -6.212467 -6.151575 -1.470982 -4.231247 -3.167786
# 3   54  10.5  NaN -3.625855 -5.459000 -1.314161 -4.055085 -2.967365
# 4   54  11.0  NaN -7.545225 -9.687892 -1.466247 -4.303337 -3.263207

# %%
comparacion.tail()
# Out:
#        DoY  Hour  NEE     NEE_f   NEE LUT   NEE anu   NEE feb   NEE jun
# 14437  355   3.5  NaN  5.796700  2.232971  2.232971  2.232971  2.232971
# 14438  355   4.0  NaN  5.550850  3.119500  3.119500  3.119500  3.119500
# 14439  355   4.5  NaN  6.036675  4.953000  4.953000  4.953000  4.953000
# 14440  355   5.0  NaN  5.285783  3.257767  3.257767  3.257767  3.257767
# 14441  355   5.5  NaN  4.252738  1.384700  1.384700  1.384700  1.384700

# %%
plt.figure(figsize=(18,9))
for i in comparacion.columns[2:]:
    plt.plot(comparacion.index/48 + 54, comparacion[i], 'o', ms = 2)
plt.legend()

# %%
for i in comparacion.columns[2:]:
    plt.figure(figsize=(18,9))
    plt.plot(comparacion.index/48 + 54, comparacion[i], 'o', ms = 2)
    plt.ylim(-30, 15)
    plt.legend()

# %%
acumulados = comparacion[:]
acumulados[comparacion.columns[2:]] = comparacion[comparacion.columns[2:]][:]*60*30

# %%
acumulados.head()
# Out:
#    DoY  Hour  NEE        NEE_f    NEE LUT      NEE anu      NEE feb  \
# 0   54   9.0  NaN -10135.56006  -8478.810 -2461.517095 -7198.456944
# 1   54   9.5  NaN  -8681.98500  -7619.490 -2206.941405 -6887.685732
# 2   54  10.0  NaN -11182.44006 -11072.835 -2647.768018 -7616.244400
# 3   54  10.5  NaN  -6526.53900  -9826.200 -2365.490556 -7299.153842
# 4   54  11.0  NaN -13581.40500 -17438.205 -2639.244170 -7746.006254
#
#        NEE jun
# 0 -5211.029786
# 1 -4871.749400
# 2 -5702.014440
# 3 -5341.256216
# 4 -5873.772047

# %%
dias = np.arange(0, 420, 60)
nee_f = list(range(1, len(dias)))
nee_lut = list(range(1, len(dias)))
nee_feb = list(range(1, len(dias)))
nee_jun = list(range(1, len(dias)))
nee_anu = list(range(1, len(dias)))
for i in list(range(1, len(dias))):
    desde = dias[i-1]
    hasta = dias[i]
    datos_bimens = acumulados[(acumulados['DoY'] >= desde)
                              & (acumulados['DoY'] < hasta)
                              ]
    nee_f[i-1] = datos_bimens['NEE_f'].sum()/1000000*44
    nee_lut[i-1] = datos_bimens['NEE LUT'].sum()/1000000*44
    nee_feb[i-1] = datos_bimens['NEE feb'].sum()/1000000*44
    nee_jun[i-1] = datos_bimens['NEE jun'].sum()/1000000*44
    nee_anu[i-1] = datos_bimens['NEE anu'].sum()/1000000*44

# %%
labels = ['49-54', 'B2', 'B3', 'B4', 'B5', '300-355']
x = np.arange(len(labels))
width = 0.15
fig, ax = plt.subplots(figsize = (18, 9))
rects1 = ax.bar(x - 2*width, nee_f, width, label='Reichestein')
rects2 = ax.bar(x - width, nee_lut, width, label='LUT')
rects3 = ax.bar(x, nee_feb, width, label='Feb')
rects3 = ax.bar(x + width, nee_jun, width, label='Jun')
rects3 = ax.bar(x + 2*width, nee_anu, width, label='Anu')
ax.set_xticks(x)
ax.set_xticklabels(labels)
metadata('Bimestre', 'g/m^2')
plt.legend(fontsize = 20)

# %%
print('Ton/ha')
# Out:
# Ton/ha

# %%
print(sum(nee_f)*1000/100000,
      sum(nee_lut)*1000/100000,
      sum(nee_anu)*1000/100000,
      sum(nee_feb)*1000/100000,
      sum(nee_jun)*1000/100000,
     )
# Out:
# -4.326902702575201 -6.988182806177094 -2.949824203831346 -3.5895983289276616 -4.462745835075285

# %%
print(sum(nee_f[2:])*1000/100000,
      sum(nee_lut[2:])*1000/100000,
      sum(nee_anu[2:])*1000/100000,
      sum(nee_feb[2:])*1000/100000,
      sum(nee_jun[2:])*1000/100000,
     )
# Out:
# -5.22649582884 -5.690457688545878 -5.538177439424924 -5.572749640264712 -5.572749640264712
